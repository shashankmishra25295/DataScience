# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split

# %%
import nltk
from nltk.tokenize import word_tokenize
import re

# %%
from sklearn.feature_extraction.text import CountVectorizer
from nltk.corpus import stopwords

# %%
df = pd.read_csv('D:/gitHubShashank/DataScience-master/Hackathons/hackathon2Greyatom/file/data/train.csv')
df.head()
# Out:
#    tweet_id                                              tweet  sentiment
# 0      1701  #sxswnui #sxsw #apple defining language of tou...          1
# 1      1851  Learning ab Google doodles! All doodles should...          1
# 2      2689  one of the most in-your-face ex. of stealing t...          2
# 3      4525  This iPhone #SXSW app would b pretty awesome i...          0
# 4      3604  Line outside the Apple store in Austin waiting...          1

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7274 entries, 0 to 7273
# Data columns (total 3 columns):
# tweet_id     7274 non-null int64
# tweet        7273 non-null object
# sentiment    7274 non-null int64
# dtypes: int64(2), object(1)
# memory usage: 170.6+ KB

# %%
df['sentiment'].value_counts()
# Out:
# 1    4311
# 2    2382
# 0     456
# 3     125
# Name: sentiment, dtype: int64

# %%
df['tidy_tweet'] = df['tweet'].str.replace("@[A-Za-z]*", "")       # removed @mention
df['tidy_tweet'] = df['tidy_tweet'].str.replace("{link}", " ")     # removed {link}

# %%
df['tidy_tweet'] = df['tidy_tweet'].str.replace("&[\w]*;", "")         # Removed &amp; and $quot; like 
df['tidy_tweet'] = df['tidy_tweet'].str.replace("[^a-zA-Z#]", " ")     # Removed all puntuations

# %%
df.head(10)
# Out:
#    tweet_id                                              tweet  sentiment  \
# 0      1701  #sxswnui #sxsw #apple defining language of tou...          1
# 1      1851  Learning ab Google doodles! All doodles should...          1
# 2      2689  one of the most in-your-face ex. of stealing t...          2
# 3      4525  This iPhone #SXSW app would b pretty awesome i...          0
# 4      3604  Line outside the Apple store in Austin waiting...          1
# 5       966  #technews One lone dude awaits iPad 2 at Apple...          1
# 6      1395  SXSW Tips, Prince, NPR Videos, Toy Shopping Wi...          1
# 7      8182  NU user RT @mention New #UberSocial for #iPhon...          1
# 8      8835     Free #SXSW sampler on iTunes {link} #FreeMusic          2
# 9       883  I think I might go all weekend without seeing ...          2
#
#                                           tidy_tweet
# 0  #sxswnui #sxsw #apple defining language of tou...
# ...

# %%
tokenized_tweet = df['tidy_tweet'].astype('str').apply(lambda x: x.split())
tokenized_tweet.head()
# Out:
# 0    [#sxswnui, #sxsw, #apple, defining, language, ...
# 1    [Learning, ab, Google, doodles, All, doodles, ...
# 2    [one, of, the, most, in, your, face, ex, of, s...
# 3    [This, iPhone, #SXSW, app, would, b, pretty, a...
# 4    [Line, outside, the, Apple, store, in, Austin,...
# Name: tidy_tweet, dtype: object

# %%
# !pip install nltk
# Out:
# ...
# You are using pip version 19.0.1, however version 19.1.1 is available.
# You should consider upgrading via the 'python -m pip install --upgrade pip' command.

# %%
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\acer\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %%
stop_words = set(stopwords.words('english'))

# %%
stop_words
# Out:
# {'a',
#  'about',
#  'above',
#  'after',
#  'again',
#  'against',
#  'ain',
#  'all',
#  'am',
#  'an',
#  'and',
#  'any',
#  'are',
#  'aren',
#  "aren't",
#  'as',
#  'at',
#  'be',
#  'because',
#  'been',
#  'before',
#  'being',
#  'below',
#  'between',
#  'both',
#  'but',
#  'by',
#  'can',
#  'couldn',
#  "couldn't",
#  'd',
#  'did',
#  'didn',
#  "didn't",
#  'do',
#  'does',
#  'doesn',
#  "doesn't",
#  'doing',
#  'don',
#  "don't",
#  'down',
#  'during',
#  'each',
#  'few',
#  'for',
#  'from',
#  'further',
#  'had',
#  'hadn',
#  "hadn't",
#  'has',
#  'hasn',
#  "hasn't",
#  'have',
#  'haven',
#  "haven't",
#  'having',
#  'he',
#  'her',
#  'here',
#  'hers',
#  'herself',
#  'him',
#  'himself',
#  'his',
#  'how',
#  'i',
#  'if',
#  'in',
#  'into',
#  'is',
#  'isn',
#  "isn't",
#  'it',
#  "it's",
#  'its',
#  'itself',
#  'just',
#  'll',
#  'm',
#  'ma',
#  'me',
#  'mightn',
#  "mightn't",
#  'more',
#  'most',
#  'mustn',
#  "mustn't",
#  'my',
# ...

# %%
df.shape
# Out:
# (7274, 4)

# %%
df['tidy_tweet']
# Out:
# 0       #sxswnui #sxsw #apple defining language of tou...
# 1       Learning ab Google doodles  All doodles should...
# 2       one of the most in your face ex  of stealing t...
# 3       This iPhone #SXSW app would b pretty awesome i...
# 4       Line outside the Apple store in Austin waiting...
# 5       #technews One lone dude awaits iPad   at Apple...
# 6       SXSW Tips  Prince  NPR Videos  Toy Shopping Wi...
# 7       NU user RT  New #UberSocial for #iPhone now in...
# 8               Free #SXSW sampler on iTunes   #FreeMusic
# 9       I think I might go all weekend without seeing ...
# 10      RT  Official #SXSW App    SXSW GO    bit ly hm...
# 11      It s official  I m buying an iPad  #SXSW #elevate
# 12      They re giving away iPad   s  x boxes and book...
# 13      RT  We re officially at #SXSW  Come by the  Gr...
# 14      #Companies to watch  from the #SXSW trade show...
# 15      RT  Google Marissa Mayer  future of location  ...
# ...

# %%
newTidyTweet = df['tidy_tweet'].str.lower()

# %%
newTidyTweet
# Out:
# ['0',
#  '#sxswnui',
#  '#sxsw',
#  '#apple',
#  'defining',
#  'language',
#  'of',
#  'tou...',
#  '1',
#  'learning',
#  'ab',
#  'google',
#  'doodles',
#  'all',
#  'doodles',
#  'should...',
#  '2',
#  'one',
#  'of',
#  'the',
#  'most',
#  'in',
#  'your',
#  'face',
#  'ex',
#  'of',
#  'stealing',
#  't...',
#  '3',
#  'this',
#  'iphone',
#  '#sxsw',
#  'app',
#  'would',
#  'b',
#  'pretty',
#  'awesome',
#  'i...',
#  '4',
#  'line',
#  'outside',
#  'the',
#  'apple',
#  'store',
#  'in',
#  'austin',
#  'waiting...',
#  '5',
#  '#technews',
#  'one',
#  'lone',
#  'dude',
#  'awaits',
#  'ipad',
#  'at',
#  'apple...',
#  '6',
#  'sxsw',
#  'tips',
#  'prince',
#  'npr',
#  'videos',
#  'toy',
#  'shopping',
#  'wi...',
#  '7',
#  'nu',
#  'user',
#  'rt',
#  'new',
#  '#ubersocial',
#  'for',
#  '#iphone',
#  'now',
#  'in...',
#  '8',
#  'free',
#  '#sxsw',
#  'sampler',
#  'on',
#  'itunes',
#  '#freemusic',
#  '9',
#  'i',
#  'think',
#  'i',
#  'might',
#  'go',
# ...

# %%
newTidyTweet = str(newTidyTweet).split()

# %%
from nltk.stem.porter import *
ps = PorterStemmer()

# %%
newTidyTweet
# Out:
# ['0',
#  '#sxswnui',
#  '#sxsw',
#  '#apple',
#  'defining',
#  'language',
#  'of',
#  'tou...',
#  '1',
#  'learning',
#  'ab',
#  'google',
#  'doodles',
#  'all',
#  'doodles',
#  'should...',
#  '2',
#  'one',
#  'of',
#  'the',
#  'most',
#  'in',
#  'your',
#  'face',
#  'ex',
#  'of',
#  'stealing',
#  't...',
#  '3',
#  'this',
#  'iphone',
#  '#sxsw',
#  'app',
#  'would',
#  'b',
#  'pretty',
#  'awesome',
#  'i...',
#  '4',
#  'line',
#  'outside',
#  'the',
#  'apple',
#  'store',
#  'in',
#  'austin',
#  'waiting...',
#  '5',
#  '#technews',
#  'one',
#  'lone',
#  'dude',
#  'awaits',
#  'ipad',
#  'at',
#  'apple...',
#  '6',
#  'sxsw',
#  'tips',
#  'prince',
#  'npr',
#  'videos',
#  'toy',
#  'shopping',
#  'wi...',
#  '7',
#  'nu',
#  'user',
#  'rt',
#  'new',
#  '#ubersocial',
#  'for',
#  '#iphone',
#  'now',
#  'in...',
#  '8',
#  'free',
#  '#sxsw',
#  'sampler',
#  'on',
#  'itunes',
#  '#freemusic',
#  '9',
#  'i',
#  'think',
#  'i',
#  'might',
#  'go',
# ...

# %%
newTidyTweet=[ps.stem(word) for word in newTidyTweet if not word in set(stopwords.words('english'))]

# %%
newTidyTweet
# Out:
# ['0',
#  '#sxswnui',
#  '#sxsw',
#  '#appl',
#  'defin',
#  'languag',
#  'tou...',
#  '1',
#  'learn',
#  'ab',
#  'googl',
#  'doodl',
#  'doodl',
#  'should...',
#  '2',
#  'one',
#  'face',
#  'ex',
#  'steal',
#  't...',
#  '3',
#  'iphon',
#  '#sxsw',
#  'app',
#  'would',
#  'b',
#  'pretti',
#  'awesom',
#  'i...',
#  '4',
#  'line',
#  'outsid',
#  'appl',
#  'store',
#  'austin',
#  'waiting...',
#  '5',
#  '#technew',
#  'one',
#  'lone',
#  'dude',
#  'await',
#  'ipad',
#  'apple...',
#  '6',
#  'sxsw',
#  'tip',
#  'princ',
#  'npr',
#  'video',
#  'toy',
#  'shop',
#  'wi...',
#  '7',
#  'nu',
#  'user',
#  'rt',
#  'new',
#  '#ubersoci',
#  '#iphon',
#  'in...',
#  '8',
#  'free',
#  '#sxsw',
#  'sampler',
#  'itun',
#  '#freemus',
#  '9',
#  'think',
#  'might',
#  'go',
#  'weekend',
#  'without',
#  'see',
#  '...',
#  '10',
#  'rt',
#  'offici',
#  '#sxsw',
#  'app',
#  'sxsw',
#  'go',
#  'bit',
#  'ly',
#  'hm...',
#  '11',
#  'offici',
#  'buy',
#  'ipad',
# ...

# %%
corpus=[]
for i in range(0,7275):
    newTidyTweet=[ps.stem(word) for word in newTidyTweet if not word in set(stopwords.words('english'))]
    newTidyTweet=' '.join(newTidyTweet)
    corpus.append(newTidyTweet)

# %%
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-45-10472ff2fbc9> in <module>()
# ----> 1 df['tidy_tweet']=newTidyTweet
#
# C:\Anaconda\lib\site-packages\pandas\core\frame.py in __setitem__(self, key, value)
#    3117         else:
#    3118             # set column
# -> 3119             self._set_item(key, value)
#    3120
#    3121     def _setitem_slice(self, key, value):
#
# C:\Anaconda\lib\site-packages\pandas\core\frame.py in _set_item(self, key, value)
#    3192
#    3193         self._ensure_valid_index(value)
# -> 3194         value = self._sanitize_column(key, value)
#    3195         NDFrame._set_item(self, key, value)
#    3196
#
# C:\Anaconda\lib\site-packages\pandas\core\frame.py in _sanitize_column(self, key, value, broadcast)
#    3389
#    3390             # turn me into an ndarray
# ...

# %%
from sklearn.feature_extraction.text import CountVectorizer
vectorizer = CountVectorizer()
X_vectorize = vectorizer.fit_transform()
# Out:
# ['0',
#  '#sxswnui',
#  '#sxsw',
#  '#apple',
#  'defining',
#  'language',
#  'of',
#  'tou...',
#  '1',
#  'learning',
#  'ab',
#  'google',
#  'doodles',
#  'all',
#  'doodles',
#  'should...',
#  '2',
#  'one',
#  'of',
#  'the',
#  'most',
#  'in',
#  'your',
#  'face',
#  'ex',
#  'of',
#  'stealing',
#  't...',
#  '3',
#  'this',
#  'iphone',
#  '#sxsw',
#  'app',
#  'would',
#  'b',
#  'pretty',
#  'awesome',
#  'i...',
#  '4',
#  'line',
#  'outside',
#  'the',
#  'apple',
#  'store',
#  'in',
#  'austin',
#  'waiting...',
#  '5',
#  '#technews',
#  'one',
#  'lone',
#  'dude',
#  'awaits',
#  'ipad',
#  'at',
#  'apple...',
#  '6',
#  'sxsw',
#  'tips',
#  'prince',
#  'npr',
#  'videos',
#  'toy',
#  'shopping',
#  'wi...',
#  '7',
#  'nu',
#  'user',
#  'rt',
#  'new',
#  '#ubersocial',
#  'for',
#  '#iphone',
#  'now',
#  'in...',
#  '8',
#  'free',
#  '#sxsw',
#  'sampler',
#  'on',
#  'itunes',
#  '#freemusic',
#  '9',
#  'i',
#  'think',
#  'i',
#  'might',
#  'go',
# ...

# %%
tokenized_tweet
# Out:
# 0       [#sxswnui, #sxsw, #apple, defining, language, ...
# 1       [Learning, ab, Google, doodles, All, doodles, ...
# 2       [one, of, the, most, in, your, face, ex, of, s...
# 3       [This, iPhone, #SXSW, app, would, b, pretty, a...
# 4       [Line, outside, the, Apple, store, in, Austin,...
# 5       [#technews, One, lone, dude, awaits, iPad, at,...
# 6       [SXSW, Tips, Prince, NPR, Videos, Toy, Shoppin...
# 7       [NU, user, RT, New, #UberSocial, for, #iPhone,...
# 8          [Free, #SXSW, sampler, on, iTunes, #FreeMusic]
# 9       [I, think, I, might, go, all, weekend, without...
# 10      [RT, Official, #SXSW, App, SXSW, GO, bit, ly, ...
# 11      [It, s, official, I, m, buying, an, iPad, #SXS...
# 12      [They, re, giving, away, iPad, s, x, boxes, an...
# 13      [RT, We, re, officially, at, #SXSW, Come, by, ...
# 14      [#Companies, to, watch, from, the, #SXSW, trad...
# 15      [RT, Google, Marissa, Mayer, future, of, locat...
# ...

# %%
df['tidy_tweet'].str.lower()
# Out:
# 0       #sxswnui #sxsw #apple defining language of tou...
# 1       learning ab google doodles  all doodles should...
# 2       one of the most in your face ex  of stealing t...
# 3       this iphone #sxsw app would b pretty awesome i...
# 4       line outside the apple store in austin waiting...
# 5       #technews one lone dude awaits ipad   at apple...
# 6       sxsw tips  prince  npr videos  toy shopping wi...
# 7       nu user rt  new #ubersocial for #iphone now in...
# 8               free #sxsw sampler on itunes   #freemusic
# 9       i think i might go all weekend without seeing ...
# 10      rt  official #sxsw app    sxsw go    bit ly hm...
# 11      it s official  i m buying an ipad  #sxsw #elevate
# 12      they re giving away ipad   s  x boxes and book...
# 13      rt  we re officially at #sxsw  come by the  gr...
# 14      #companies to watch  from the #sxsw trade show...
# 15      rt  google marissa mayer  future of location  ...
# ...

# %%
from nltk.stem.porter import *
stemmer = PorterStemmer()

beforeStemming = df['tidy_tweet']
beforeStemming= beforeStemming.apply(lambda x: [stemmer.stem(i) for i in x]) # stemming
beforeStemming
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-17-d957e1d0a226> in <module>()
#       3
#       4 beforeStemming = df['tidy_tweet']
# ----> 5 beforeStemming= beforeStemming.apply(lambda x: [stemmer.stem(i) for i in x]) # stemming
#       6 beforeStemming
#
# C:\Anaconda\lib\site-packages\pandas\core\series.py in apply(self, func, convert_dtype, args, **kwds)
#    3192             else:
#    3193                 values = self.astype(object).values
# -> 3194                 mapped = lib.map_infer(values, f, convert=convert_dtype)
#    3195
#    3196         if len(mapped) and isinstance(mapped[0], Series):
#
# pandas/_libs/src\inference.pyx in pandas._libs.lib.map_infer()
#
# <ipython-input-17-d957e1d0a226> in <lambda>(x)
#       3
#       4 beforeStemming = df['tidy_tweet']
# ...

# %%
for i in range(len(beforeStemming)):
    beforeStemming[i] = ''.join(beforeStemming[i])

afterStemming = beforeStemming
afterStemming

# %%
afterStemming.str.lower()

# %%
df['tidy_tweet']=afterStemming
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-18-88efe7fe9249> in <module>()
# ----> 1 df['tidy_tweet']=afterStemming
#
# NameError: name 'afterStemming' is not defined

# %%
all_words = ' '.join([text for text in df['tidy_tweet']])
from wordcloud import WordCloud
wordcloud = WordCloud(width=800, height=500, random_state=21, max_font_size=110).generate(all_words)

plt.figure(figsize=(10, 7))
plt.imshow(wordcloud, interpolation="bilinear")
plt.axis('off')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-36-20e52c1cc77c> in <module>()
# ----> 1 all_words = ' '.join([text for text in df['tidy_tweet']])
#       2 from wordcloud import WordCloud
#       3 wordcloud = WordCloud(width=800, height=500, random_state=21, max_font_size=110).generate(all_words)
#       4
#       5 plt.figure(figsize=(10, 7))
#
# TypeError: sequence item 1274: expected str instance, float found

# %%
normal_words =' '.join([text for text in df['tidy_tweet'][df['sentiment'] == 0]])

wordcloud = WordCloud(width=800, height=500, random_state=21, max_font_size=110).generate(normal_words)
plt.figure(figsize=(10, 7))
plt.imshow(wordcloud, interpolation="bilinear")
plt.axis('off')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-35-b5a7e5f29748> in <module>()
#       1 normal_words =' '.join([text for text in df['tidy_tweet'][df['sentiment'] == 0]])
#       2
# ----> 3 wordcloud = WordCloud(width=800, height=500, random_state=21, max_font_size=110).generate(normal_words)
#       4 plt.figure(figsize=(10, 7))
#       5 plt.imshow(wordcloud, interpolation="bilinear")
#
# NameError: name 'WordCloud' is not defined

# %%
df['tidy_tweet']=tokenized_tweet
