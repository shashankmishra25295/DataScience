# %%
import math
import numpy as np
import matplotlib.pyplot as plt

# %%
x = np.arange(0,10,0.1)

# %%
y = x - x**3/math.factorial(3) + x**5/math.factorial(5) - x**7/math.factorial(7)+x**9/math.factorial(9) - x**11/math.factorial(11)

# %%
plt.plot(np.sin(y))
