# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
import seaborn as sns

# %%
data = pd.read_csv('D:/DataScience/DataSets/insurance.csv')
data.head()
# Out:
#    age     sex     bmi  children smoker     region      charges
# 0   19  female  27.900         0    yes  southwest  16884.92400
# 1   18    male  33.770         1     no  southeast   1725.55230
# 2   28    male  33.000         3     no  southeast   4449.46200
# 3   33    male  22.705         0     no  northwest  21984.47061
# 4   32    male  28.880         0     no  northwest   3866.85520

# %%
# Creating x_train data set after droping target column ie charges
x_train = data.drop(['charges'],axis=1)
x_train.head()
# Out:
#    age     sex     bmi  children smoker     region
# 0   19  female  27.900         0    yes  southwest
# 1   18    male  33.770         1     no  southeast
# 2   28    male  33.000         3     no  southeast
# 3   33    male  22.705         0     no  northwest
# 4   32    male  28.880         0     no  northwest

# %%
data.describe()
# Out:
#                age          bmi     children       charges
# count  1338.000000  1338.000000  1338.000000   1338.000000
# mean     39.207025    30.663397     1.094918  13270.422265
# std      14.049960     6.098187     1.205493  12110.011237
# min      18.000000    15.960000     0.000000   1121.873900
# 25%      27.000000    26.296250     0.000000   4740.287150
# 50%      39.000000    30.400000     1.000000   9382.033000
# 75%      51.000000    34.693750     2.000000  16639.912515
# max      64.000000    53.130000     5.000000  63770.428010

# %%
# all numeric columns in numericDataFrame
numericDataFrame = list(data._get_numeric_data().columns)
numericDataFrame
# Out:
# ['age', 'bmi', 'children', 'charges']

# %%
# all categorical columns in categorical_feature_columns
categorical_feature_columns = list(set(data.columns) - set(data._get_numeric_data().columns))
categorical_feature_columns
# Out:
# ['smoker', 'region', 'sex']

# %%
# Histograms
x_train = data.drop(['charges'],axis=1)

# %%
num_cols = ['age', 'bmi', 'children']
for i in range(0,len(num_cols),2):
    if len(num_cols) > i+1:
        plt.figure(figsize=(10,4))
        plt.subplot(121)
        sns.distplot(data[num_cols[i]],hist=True, kde=True)
        plt.subplot(122)            
        sns.distplot(data[num_cols[i+1]], hist=True,kde=True)
        plt.tight_layout()
        plt.show()

    else:
        sns.distplot(data[num_cols[i]],hist=True, kde=True)
# Out:
# C:\Anaconda\lib\site-packages\scipy\stats\stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %%
# BoxPlots
# Bmi contains outliers
num_cols = ['age', 'bmi', 'children']
for i in range(0,len(num_cols),2):
    if len(num_cols) > i+1:
        plt.figure(figsize=(10,5))
        plt.subplot(121)
        sns.boxplot(facet, num_cols[i],data = data)
        plt.subplot(122)            
        sns.boxplot(facet, num_cols[i+1],data = data)
        plt.tight_layout()
        plt.show()

    else:
        sns.boxplot(facet, num_cols[i],data = data)

# %%
sns.countplot(y=data['region'])

# %%
sns.lmplot('age', 'bmi', data=data, fit_reg=True)
# Out:
# C:\Anaconda\lib\site-packages\scipy\stats\stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %%
sns.jointplot('age', 'bmi', data=data, kind='reg')
# Out:
# C:\Anaconda\lib\site-packages\scipy\stats\stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %%
sns.jointplot('age', 'bmi', data=data, kind='hex')
# Out:
# C:\Anaconda\lib\site-packages\scipy\stats\stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %%
plt.figure(figsize=(12,8))
sns.heatmap(data.corr(), annot=True,cmap='viridis')

# %%
data['age_sqaure'] = data['age']**2
data['age_cube'] = data['age']**3
data['bmi_square'] = data['bmi']**2
data['bmi_cube'] = data['bmi']**3

# %%
plt.figure(figsize=(12,8))
sns.heatmap(data.corr(), annot=True,cmap='viridis')

# %%
data['charges_log'] = np.log(data['charges'])

# %%
plt.figure(figsize=(12,8))
sns.heatmap(data.corr(), annot=True,cmap='viridis')

# %%
data['age_square_root'] = np.sqrt(data['age'])

# %%
plt.figure(figsize=(12,8))
sns.heatmap(data.corr(), annot=True,cmap='viridis')

# %%
data.columns
# Out:
# Index(['age', 'sex', 'bmi', 'children', 'smoker', 'region', 'charges',
#        'age_sqaure', 'age_cube', 'bmi_square', 'bmi_cube', 'charges_log',
#        'age_square_root'],
#       dtype='object')

# %%
charges_and_age_sqaure = data[['age_sqaure','age_cube','age_square_root','charges','charges_log']]
plt.figure(figsize=(12,8))
sns.heatmap(charges_and_age_sqaure.corr(), annot=True,cmap='viridis')

# %%
data['charges_log_log']  = np.log(data['charges_log'])

# %%
plt.figure(figsize=(12,8))
sns.heatmap(data.corr(), annot=True,cmap='viridis')

# %%
data['charges_log_log_log']  = np.log(data['charges_log_log'])

# %%
plt.figure(figsize=(12,8))
sns.heatmap(data.corr(), annot=True,cmap='viridis')

# %%
data['charges_log_log_log_sqrt']  = np.sqrt(data['charges_log_log_log'])

# %%
plt.figure(figsize=(12,8))
sns.heatmap(data.corr(), annot=True,cmap='viridis')

# %%
data.drop(['charges_log_log_log_sqrt'],axis=1).columns
# Out:
# Index(['age', 'sex', 'bmi', 'children', 'smoker', 'region', 'charges',
#        'age_sqaure', 'age_cube', 'bmi_square', 'bmi_cube', 'charges_log',
#        'age_square_root', 'charges_log_log', 'charges_log_log_log'],
#       dtype='object')

# %%
from sklearn.linear_model import LinearRegression

x = np.array(range(100)).reshape(-1, 1)
y = np.array(range(100))

linearRegression = LinearRegression()

linearRegression.fit(x,y)

y_pred = linearRegression.predict(x)

# %%
linearRegression.coef_
# Out:
# array([1.])

# %%
linearRegression.intercept_
# Out:
# -1.4210854715202004e-14

# %%
plt.plot(x,y_pred)

# %%
y[4] = 120
y[10] = 150
y[15] = 130
y[41] = 180

# %%
linearRegression.fit(x,y)

y_pred = linearRegression.predict(x)

# %%
plt.scatter(x,y)
plt.plot(x,y_pred)

# %%
sns.distplot(data['charges'])
# Out:
# C:\Anaconda\lib\site-packages\scipy\stats\stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %%
data.charges.skew()
# Out:
# 1.5158796580240388

# %%
data['charges_log10'] = np.log10(data['charges'])

# %%
sns.distplot(data['charges_log10'])
# Out:
# C:\Anaconda\lib\site-packages\scipy\stats\stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %%
data['charges_log10'].skew()
# Out:
# -0.09009752473025416

# %%
mean = np.mean(data.charges_log10)
mean
# Out:
# 3.9514972789100242

# %%
data['charges_log10'].std()
# Out:
# 0.39934555110640224

# %%
sample_data = pd.read_csv('D:/DataScience/DataSets/sample_data.csv')
sample_data.head(20)
# Out:
#     car_ID  symboling                   CarName fueltype aspiration  \
# 0        1          3        alfa-romero giulia      gas        std
# 1        2          3       alfa-romero stelvio      gas        std
# 2        3          1  alfa-romero Quadrifoglio      gas        std
# 3        4          2               audi 100 ls      gas        std
# 4        5          2                audi 100ls      gas        std
# 5        6          2                  audi fox      gas        std
# 6        7          1                audi 100ls      gas        std
# 7        8          1                 audi 5000      gas        std
# 8        9          1                 audi 4000      gas      turbo
# 9       10          0       audi 5000s (diesel)      gas      turbo
# 10      11          2                  bmw 320i      gas        std
# 11      12          0                  bmw 320i      gas        std
# 12      13          0                    bmw x1      gas        std
# ...

# %%
sample_data['doornumber'].value_counts()
# Out:
# four    115
# two      90
# Name: doornumber, dtype: int64

# %%
sample_data['doornumber'].replace({"four":4,"two":2},inplace=True)
sample_data.head(10)
# Out:
#    car_ID  symboling                   CarName fueltype aspiration  \
# 0       1          3        alfa-romero giulia      gas        std
# 1       2          3       alfa-romero stelvio      gas        std
# 2       3          1  alfa-romero Quadrifoglio      gas        std
# 3       4          2               audi 100 ls      gas        std
# 4       5          2                audi 100ls      gas        std
# 5       6          2                  audi fox      gas        std
# 6       7          1                audi 100ls      gas        std
# 7       8          1                 audi 5000      gas        std
# 8       9          1                 audi 4000      gas      turbo
# 9      10          0       audi 5000s (diesel)      gas      turbo
#
#    doornumber      carbody drivewheel enginelocation  wheelbase    ...      \
# 0           2  convertible        rwd          front       88.6    ...
# 1           2  convertible        rwd          front       88.6    ...
# ...
